# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from pandas import datetime

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import statsmodels.api as sm
import scipy.stats as stats
from statsmodels.distributions.empirical_distribution import ECDF
from sklearn.preprocessing import StandardScaler

# time series analysis
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# prophet by Facebook
from fbprophet import Prophet
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-26d7fa21-c703-48af-a334-2bc5c7cbffae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26d7fa21-c703-48af-a334-2bc5c7cbffae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample_submission.csv to sample_submission (1).csv
# Saving store.csv to store (1).csv
# Saving test.csv to test (1).csv
# Saving train.csv to train (1).csv

# %%
import io 
train = pd.read_csv(io.BytesIO(uploaded['train.csv']), parse_dates = True, low_memory = False, index_col = 'Date' )
test = pd.read_csv(io.BytesIO(uploaded['test.csv']))
store = pd.read_csv(io.BytesIO(uploaded['store.csv']))
train_all = pd.read_csv(io.BytesIO(uploaded['train.csv']), parse_dates = True, low_memory = False, index_col = 'Date' )

# %%
#customer vs sales
a = train_all[train_all.Open ==1]
sns.lineplot(x = 'Customers', y = 'Sales', data=a)

# %%
print("In total: ", train.shape)
train.head()
# Out:
# In total:  (1017209, 8)
#             Store  DayOfWeek  Sales  ...  Promo  StateHoliday  SchoolHoliday
# Date                                 ...
# 2015-07-31      1          5   5263  ...      1             0              1
# 2015-07-31      2          5   6064  ...      1             0              1
# 2015-07-31      3          5   8314  ...      1             0              1
# 2015-07-31      4          5  13995  ...      1             0              1
# 2015-07-31      5          5   4822  ...      1             0              1
#
# [5 rows x 8 columns]

# %%
train.index
# Out:
# DatetimeIndex(['2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31',
#                ...
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01'],
#               dtype='datetime64[ns]', name='Date', length=1017209, freq=None)

# %% [markdown]
# #Exploratory Data Analysis

# %%
# Train data
print("In total: ", train.shape)
train.head()
# Out:
# In total:  (1017209, 8)
#             Store  DayOfWeek  Sales  ...  Promo  StateHoliday  SchoolHoliday
# Date                                 ...
# 2015-07-31      1          5   5263  ...      1             0              1
# 2015-07-31      2          5   6064  ...      1             0              1
# 2015-07-31      3          5   8314  ...      1             0              1
# 2015-07-31      4          5  13995  ...      1             0              1
# 2015-07-31      5          5   4822  ...      1             0              1
#
# [5 rows x 8 columns]

# %%
# Test data
print("In total: ", test.shape)
test.head()
# Out:
# In total:  (41088, 8)
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
# data extraction
train['Year'] = train.index.year
train['Month'] = train.index.month
train['Day'] = train.index.day
train['WeekOfYear'] = train.index.weekofyear

# adding new variable
train['SalePerCustomer'] = train['Sales']/train['Customers']
train['SalePerCustomer'].describe()
# Out:
# count    844340.000000
# mean          9.493619
# std           2.197494
# min           0.000000
# 25%           7.895563
# 50%           9.250000
# 75%          10.899729
# max          64.957854
# Name: SalePerCustomer, dtype: float64

# %% [markdown]
# ##ECDF: empirical cumulative distribution function

# %%
# ECDF: empirical cumulative distribution function
sns.set(style = "ticks")# to format into seaborn 
c = '#386B7F' # basic color for plots
plt.figure(figsize = (12, 6))

plt.subplot(311)
cdf = ECDF(train['Sales'])
plt.plot(cdf.x, cdf.y, label = "statmodels", color = c);
plt.xlabel('Sales'); plt.ylabel('ECDF');

# plot second ECDF  
plt.subplot(312)
cdf = ECDF(train['Customers'])
plt.plot(cdf.x, cdf.y, label = "statmodels", color = c);
plt.xlabel('Customers');

# plot second ECDF  
plt.subplot(313)
cdf = ECDF(train['SalePerCustomer'])
plt.plot(cdf.x, cdf.y, label = "statmodels", color = c);
plt.xlabel('Sale per Customer');

# %% [markdown]
# ##Missing values

# %% [markdown]
# ###Closed stores and zero sales stores

# %%
# closed stores
closed_stores = train[(train.Open == 0) & (train.Sales == 0)]
print("In total: ", closed_stores.shape)
closed_stores.head()
# Out:
# In total:  (172817, 13)
#             Store  DayOfWeek  Sales  ...  Day  WeekOfYear  SalePerCustomer
# Date                                 ...
# 2015-07-31    292          5      0  ...   31          31              NaN
# 2015-07-31    876          5      0  ...   31          31              NaN
# 2015-07-30    292          4      0  ...   30          31              NaN
# 2015-07-30    876          4      0  ...   30          31              NaN
# 2015-07-29    292          3      0  ...   29          31              NaN
#
# [5 rows x 13 columns]

# %%
# opened stores with zero sales
zero_sales = train[(train.Open != 0) & (train.Sales == 0)]
print("In total: ", zero_sales.shape)
zero_sales.head(5)
# Out:
# In total:  (54, 13)
#             Store  DayOfWeek  Sales  ...  Day  WeekOfYear  SalePerCustomer
# Date                                 ...
# 2015-05-15    971          5      0  ...   15          20              NaN
# 2015-03-26    674          4      0  ...   26          13              NaN
# 2015-02-05    699          4      0  ...    5           6              NaN
# 2014-10-01    708          3      0  ...    1          40              NaN
# 2014-09-22    357          1      0  ...   22          39              NaN
#
# [5 rows x 13 columns]

# %%
#Removing closed stores
print("Closed stores and days which didn't have any sales won't be counted into the forecasts.")
train = train[(train["Open"] != 0) & (train['Sales'] != 0)]

print("In total: ", train.shape)
# Out:
# Closed stores and days which didn't have any sales won't be counted into the forecasts.
# In total:  (844338, 13)

# %%
# store data
print("In total: ", store.shape)
store.head()
# Out:
# In total:  (1115, 10)
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             NaN              NaN
# 4      5         a  ...             NaN              NaN
#
# [5 rows x 10 columns]

# %%
# missing values
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
# missing values in CompetitionDistance
store[pd.isnull(store.CompetitionDistance)]
# Out:
#      Store StoreType  ... Promo2SinceYear    PromoInterval
# 290    291         d  ...             NaN              NaN
# 621    622         a  ...             NaN              NaN
# 878    879         d  ...          2013.0  Feb,May,Aug,Nov
#
# [3 rows x 10 columns]

# %%
# fill NaN with a median value (skewed distribuion)
# since no particular pattern observed in the missing values
store['CompetitionDistance'].fillna(store['CompetitionDistance'].median(), inplace = True)

# %%
_ = store[pd.isnull(store.CompetitionOpenSinceYear)]
_[_.CompetitionDistance != 0].shape
# Out:
# (354, 10)

# %%
_ = store[pd.isnull(store.CompetitionOpenSinceMonth)]
_[_.CompetitionDistance != 0].shape
# Out:
# (354, 10)

# %%
_ = store[pd.isnull(store.Promo2SinceWeek)]
_[_.Promo2 != 0].shape
# Out:
# (0, 10)

# %%
# no promo = no information about the promo?
_ = store[pd.isnull(store.Promo2SinceYear)]
_[_.Promo2 != 0].shape
# Out:
# (0, 10)

# %%
# replace NA's by 0
store.fillna(0, inplace = True)

# %%
print("Joining train set with an additional store information.")

# by specifying inner join we make sure that only those observations 
# that are present in both train and store sets are merged together
train_store = pd.merge(train, store, how = 'inner', on = 'Store')

print("In total: ", train_store.shape)
train_store.head()
# Out:
# Joining train set with an additional store information.
# In total:  (844338, 22)
#    Store  DayOfWeek  Sales  ...  Promo2SinceWeek  Promo2SinceYear  PromoInterval
# 0      1          5   5263  ...              0.0              0.0              0
# 1      1          4   5020  ...              0.0              0.0              0
# 2      1          3   4782  ...              0.0              0.0              0
# 3      1          2   5011  ...              0.0              0.0              0
# 4      1          1   6102  ...              0.0              0.0              0
#
# [5 rows x 22 columns]

# %% [markdown]
# ##Store types

# %%
# store types
train_store.groupby('StoreType')['Sales'].describe()
# Out:
#               count          mean          std  ...     50%       75%      max
# StoreType                                       ...
# a          457042.0   6925.697986  3277.351589  ...  6285.0   8406.00  41551.0
# b           15560.0  10233.380141  5155.729868  ...  9130.0  13184.25  38722.0
# c          112968.0   6933.126425  2896.958579  ...  6408.0   8349.25  31448.0
# d          258768.0   6822.300064  2556.401455  ...  6395.0   8123.25  38037.0
#
# [4 rows x 8 columns]

# %%
def find_outliers(df, var):
    
    df.boxplot(var)
    plt.title(var)
    plt.ylabel(var)
    plt.show()
    
for var in ['Sales','SalePerCustomer','CompetitionDistance', 'Customers']:
    find_outliers(train_store, var)

# %%
'''def iqr_outlier_treatment(df, var):
 Q1=df.quantile(0.25)
 Q3=df.quantile(0.75)
 IQR=Q3-Q1
 Lower_Whisker = Q1-1.5*IQR
 Upper_Whisker = Q3+1.5*IQR
 return var[df < Upper_Whisker].copy()

for var in ['Sales','SalePerCustomer','CompetitionDistance', 'Customers']:
  iqr_outlier_treatment(train_store, var)'''
# Out:
# "def iqr_outlier_treatment(df, var):\n Q1=df.quantile(0.25)\n Q3=df.quantile(0.75)\n IQR=Q3-Q1\n Lower_Whisker = Q1-1.5*IQR\n Upper_Whisker = Q3+1.5*IQR\n return var[df < Upper_Whisker].copy()\n\nfor var in ['Sales','SalePerCustomer','CompetitionDistance', 'Customers']:\n  iqr_outlier_treatment(train_store, var)"

# %%
# overall sum of Sales and Customers for each store type
train_store.groupby('StoreType')['Customers', 'Sales'].sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            Customers       Sales
# StoreType
# a          363541431  3165334859
# b           31465616   159231395
# c           92129705   783221426
# d          156904995  1765392943

# %%
# sales trends
sns.factorplot(data = train_store, x = 'Month', y = "Sales", 
               col = 'StoreType', # per store type in cols
               palette = 'plasma',
               hue = 'StoreType',
               row = 'Promo', # per promo in the store in rows
               color = c)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
# sale per customer trends
sns.factorplot(data = train_store, x = 'Month', y = "SalePerCustomer", 
               col = 'StoreType', # per store type in cols
               palette = 'plasma',
               hue = 'StoreType',
               row = 'Promo', # per promo in the store in rows
               color = c)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
# sale per promo
sns.factorplot(data = train_store, x = 'Month', y = "Sales", 
               palette = 'plasma',
               hue = 'Promo',
               color = c)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
# Customer Vs promo
sns.factorplot(data = train_store, x = 'Month', y = "Customers", 
               palette = 'plasma',
               hue = 'Promo',
               color = c)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
# Assortment type
sns.factorplot(data = train_store, x = 'Month', y = "Sales", 
               palette = 'plasma',
               hue = 'Assortment',
               color = c)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
# customers
sns.factorplot(data = train_store, x = 'Month', y = "Sales", 
               col = 'DayOfWeek', # per store type in cols
               palette = 'plasma',
               hue = 'StoreType',
               row = 'StoreType', # per store type in rows
               color = c)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
# stores which are opened on Sundays
train_store[(train_store.Open == 1) & (train_store.DayOfWeek == 7)]['Store'].unique()
# Out:
# array([  85,  122,  209,  259,  262,  274,  299,  310,  335,  353,  423,
#         433,  453,  494,  512,  524,  530,  562,  578,  676,  682,  732,
#         733,  769,  863,  867,  877,  931,  948, 1045, 1081, 1097, 1099])

# %%
# competition open time (in months)
train_store['CompetitionOpen'] = 12 * (train_store.Year - train_store.CompetitionOpenSinceYear) + \
        (train_store.Month - train_store.CompetitionOpenSinceMonth)
    
# Promo open time
train_store['PromoOpen'] = 12 * (train_store.Year - train_store.Promo2SinceYear) + \
        (train_store.WeekOfYear - train_store.Promo2SinceWeek) / 4.0

# replace NA's by 0
train_store.fillna(0, inplace = True)

# average PromoOpen time and CompetitionOpen time per store type
train_store.loc[:, ['StoreType', 'Sales', 'Customers', 'PromoOpen', 'CompetitionOpen']].groupby('StoreType').mean()
# Out:
#                   Sales    Customers     PromoOpen  CompetitionOpen
# StoreType
# a           6925.697986   795.422370  12918.492198      7115.514452
# b          10233.380141  2022.211825  17199.328069     11364.495244
# c           6933.126425   815.538073  12158.636107      6745.418694
# d           6822.300064   606.353935  10421.916846      9028.526526

# %% [markdown]
# ##correlational analysis

# %%
# Compute the correlation matrix 
# exclude 'Open' variable
corr_all = train_store.drop('Open', axis = 1).corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr_all, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize = (11, 9))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_all, mask = mask,
            square = True, linewidths = .5, ax = ax, cmap = "BuPu")      
plt.show()

# %%
# sale per customer trends
sns.factorplot(data = train_store, x = 'DayOfWeek', y = "Sales", 
               col = 'Promo', 
               row = 'Promo2',
               hue = 'Promo2',
               palette = 'RdPu')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
# sale per customer trends
sns.factorplot(data = train_store, x = 'DayOfWeek', y = "Customers", 
               col = 'Promo', 
               row = 'Promo2',
               hue = 'Promo2',
               palette = 'RdPu')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %% [markdown]
# ##Time-Series Analysis per Store Type

# %%
# preparation: input should be float type
train['Sales'] = train['Sales'] * 1.0

# store types
sales_a = train[train.Store == 2]['Sales']
sales_b = train[train.Store == 85]['Sales'].sort_index(ascending = True) # solve the reverse order
sales_c = train[train.Store == 1]['Sales']
sales_d = train[train.Store == 13]['Sales']

f, (ax1, ax2, ax3, ax4) = plt.subplots(4, figsize = (12, 13))
# store types
sales_a.resample('W').sum().plot(color = c, ax = ax1)
sales_b.resample('W').sum().plot(color = c, ax = ax2)
sales_c.resample('W').sum().plot(color = c, ax = ax3)
sales_d.resample('W').sum().plot(color = c, ax = ax4)

# %%
sns.lineplot(x = 'Customers', y = 'Sales', data=train_store)

# %%
sns.lineplot(x = 'CompetitionDistance', y= 'Sales', data=train_store)

# %% [markdown]
# #Time Series Analysis and Forecasting with Prophet

# %%
# importing data
df = pd.read_csv(io.BytesIO(uploaded['train.csv']),  low_memory = False)

# remove closed stores and those with no sales
df = df[(df["Open"] != 0) & (df['Sales'] != 0)]

# sales for the store number 1 (StoreType C)
sales = df[df.Store == 1].loc[:, ['Date', 'Sales']]

# reverse to the order: from 2013 to 2015
sales = sales.sort_index(ascending = False)

# to datetime64
sales['Date'] = pd.DatetimeIndex(sales['Date'])
sales.dtypes
# Out:
# Date     datetime64[ns]
# Sales             int64
# dtype: object

# %%
# from the prophet documentation every variables should have specific names
sales = sales.rename(columns = {'Date': 'ds',
                                'Sales': 'y'})
sales.head()
# Out:
#                 ds     y
# 1014980 2013-01-02  5530
# 1013865 2013-01-03  4327
# 1012750 2013-01-04  4486
# 1011635 2013-01-05  4997
# 1009405 2013-01-07  7176

# %%
# plot daily sales
ax = sales.set_index('ds').plot(figsize = (12, 4), color = c)
ax.set_ylabel('Daily Number of Sales')
ax.set_xlabel('Date')
plt.show()

# %% [markdown]
# ##Modeling Holidays

# %%
# create holidays dataframe
state_dates = df[(df.StateHoliday == 'a') | (df.StateHoliday == 'b') & (df.StateHoliday == 'c')].loc[:, 'Date'].values
school_dates = df[df.SchoolHoliday == 1].loc[:, 'Date'].values

state = pd.DataFrame({'holiday': 'state_holiday',
                      'ds': pd.to_datetime(state_dates)})
school = pd.DataFrame({'holiday': 'school_holiday',
                      'ds': pd.to_datetime(school_dates)})

holidays = pd.concat((state, school))      
holidays.head()
# Out:
#          holiday         ds
# 0  state_holiday 2015-06-04
# 1  state_holiday 2015-06-04
# 2  state_holiday 2015-06-04
# 3  state_holiday 2015-06-04
# 4  state_holiday 2015-06-04

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model = Prophet(interval_width = 0.95, 
                   holidays = holidays)
my_model.fit(sales)

# dataframe that extends into future 6 weeks 
future_dates = my_model.make_future_dataframe(periods = 6*7)

print("First week to forecast.")
future_dates.tail(7)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# First week to forecast.
#             ds
# 816 2015-09-05
# 817 2015-09-06
# 818 2015-09-07
# 819 2015-09-08
# 820 2015-09-09
# 821 2015-09-10
# 822 2015-09-11

# %%
# predictions
forecast = my_model.predict(future_dates)

# preditions for last week
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 816 2015-09-05  4092.135712  2558.155262  5598.288410
# 817 2015-09-06  4087.032784  2492.483978  5750.421449
# 818 2015-09-07  4161.813517  2608.949695  5693.896058
# 819 2015-09-08  3664.142168  2028.165461  5384.684212
# 820 2015-09-09  3550.915165  1884.042434  5218.853300
# 821 2015-09-10  3462.435748  1757.349577  5116.924097
# 822 2015-09-11  3717.122489  2148.121085  5453.685768

# %%
fc = forecast[['ds', 'yhat']].rename(columns = {'Date': 'ds', 'Forecast': 'yhat'})

# %%
# visualizing predicions
my_model.plot(forecast);

# %%
my_model.plot_components(forecast);
